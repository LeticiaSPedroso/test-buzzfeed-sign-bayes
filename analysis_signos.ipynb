# %% [markdown]
# # Dataset analysis

# %% [markdown]
# Documentation pandas and matplotlib

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Form dos signos.csv')

# %%
df
# Out:
#    Carimbo de data/hora Qual palavra melhor te descreve?  \
# 0   28/01/2020 11:22:06                         Racional
# 1   28/01/2020 11:33:08                         Racional
# 2   28/01/2020 11:37:16                         Sociável
# 3   28/01/2020 11:37:52                         Paciente
# 4   28/01/2020 11:43:26                        Reservado
# 5   28/01/2020 11:44:19                         Racional
# 6   28/01/2020 11:44:56                        Confiável
# 7   28/01/2020 11:45:55                         Racional
# 8   28/01/2020 11:46:35                         Sociável
# 9   28/01/2020 11:47:04                        Reservado
# 10  28/01/2020 11:49:50                        Carinhoso
# 11  28/01/2020 11:49:54                         Sociável
# 12  28/01/2020 11:50:42                         Racional
# 13  28/01/2020 12:01:22                         Racional
# 14  28/01/2020 12:25:02                        Confiável
# ...

# %%
df2 = df.drop(columns='Carimbo de data/hora')

# %%
df2.describe()
# Out:
#        Qual palavra melhor te descreve? Qual animal você se identifica?  \
# count                                81                              81
# unique                                9                              10
# top                           Reservado                            Lobo
# freq                                 21                              18
#
#        Emprego dos seus sonhos? Que tipo de amigo você é?  \
# count                        81                        81
# unique                       10                        10
# top                    Escritor               Conselheiro
# freq                         18                        21
#
#        Uma diva pop que você se identifica: Qual é o seu signo?
# count                                    81                  81
# unique                                    9                  12
# top                                 Beyoncé              Gêmeos
# ...

# %%
count = df['Qual é o seu signo?'].value_counts() 
print(count)
# Out:
# Gêmeos         10
# Touro           9
# Câncer          9
# Aquário         8
# Escorpião       8
# Libra           8
# Capricórnio     8
# Áries           5
# Sagitário       5
# Peixes          5
# Leão            4
# Virgem          2
# Name: Qual é o seu signo?, dtype: int64

# %%
count = df.groupby(['Qual é o seu signo?', 'Emprego dos seus sonhos?']).size() 
print(count)
# Out:
# Qual é o seu signo?  Emprego dos seus sonhos?
# Aquário              Designer                    1
#                      Escritor                    5
#                      Músico                      1
#                      Piloto                      1
# Capricórnio          Diretor de cinema           2
#                      Escritor                    2
#                      Músico                      3
#                      Piloto                      1
# Câncer               Ator/Atriz                  1
#                      Designer                    1
#                      Escritor                    2
#                      Estilista                   1
#                      Fotógrafo                   2
#                      Personal Trainer            1
#                      Piloto                      1
# Escorpião            Desenhista                  1
#                      Designer                    1
# ...

# %%
df2.groupby(['Qual é o seu signo?','Qual animal você se identifica?']).size().unstack().plot(kind='bar',stacked=True,figsize=(15,10))
plt.show()

# %%
df2.groupby(['Qual é o seu signo?','Uma diva pop que você se identifica:']).size().unstack().plot(kind='bar',stacked=True,figsize=(17,10))
plt.show()
